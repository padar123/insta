# %%
import instaloader

# Replace 'your_username' and 'your_password' with your actual Instagram credentials
L = instaloader.Instaloader()
username = 'padar_ind'
password = 'password_yours'

try:
    # L.context.log_in(username, password)
    L.login(username, password)
except Exception as e:
    print(f"Login failed: {e}")
    exit()

# Replace 'target_account_insta_handle' with the username of the account you want to get followers from
profile = instaloader.Profile.from_username(L.context, 'padar_ind')

followers = []
for follower in profile.get_followers():
    followers.append(follower.username)

# Save the list of followers to a text file
# with open('followers.txt', 'w') as f:
#     for follower in followers:
#         f.write(f"{follower}\n")

# print(f"Followers saved to 'followers.txt'")
followers
# Out:
# ['sayoni8213',
#  '_adyashabehera',
#  'nishit_63',
#  'artist_arti.03',
#  'soumyasb2006',
#  'sahil_ku_11',
#  'shubham_verma_181',
#  '03arnav9',
#  '_imnot_dead_',
#  '_adi_tea_yeah_',
#  'sancchhita',
#  'soumya_05mohanty',
#  'rajalaxmi_bai',
#  'prachipratikhya_27',
#  'queen_priti_1_2_',
#  'atty.subhrajyoti',
#  'pratyush_kumar_sahu23',
#  'me_luciess',
#  'swasteek._7',
#  '_anshuman_p_',
#  'sgt.sameer123',
#  'mona____lisha_____',
#  'subhra__dash',
#  'ankittmohantty',
#  'not_khushi2004',
#  '__santosh_dalei___2005',
#  'gincyrenish',
#  'hansita_samantray',
#  'i_amdkd',
#  'niranjan.dash.58',
#  'neel__1201',
#  'shyamsunad__77',
#  'star_lord.ashu',
#  '_praptii.14',
#  '_.kiransai._',
#  'shreshtha_pattnaik',
#  '_.kulcha._20',
#  'abhijeettt.w_',
#  'dinesh25214',
#  'rutuparna_mishra19',
#  'jazz_scotch_',
#  'anindita7943',
#  'karansharma8259',
#  'll_sahani_babu_ll',
#  '_.hades._958',
#  'smurty_sneha',
#  'eng_battot',
#  'dharani_kumar_',
#  'bapubapu2352',
# ...

# %%
pip install instaloader
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.6/64.6 kB 1.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for instaloader: filename=instaloader-4.12-py3-none-any.whl size=66747 sha256=c8d09b6d7766b3669139efae664eb60929dbb15499992103c8020c9cf6cdfaaf
#   Stored in directory: /root/.cache/pip/wheels/22/ca/b6/7f3328e7b9fddcfada249d7d4f9a3eacb3326c3fd23433a1d4
# Successfully built instaloader
# ...

# %%
followings = []

# Iterate over the profiles the target profile follows
for following in profile.get_followees():
    # Append the username of each following to the list
    followings.append(following.username)
followings
# Out:
# ['sayoni8213',
#  'side_end_developer__',
#  'hiten.codes',
#  '_adyashabehera',
#  'sheenamgautam',
#  'smurty_sneha',
#  '_.bandita_das._',
#  'fecpodcast',
#  'zorothewiz',
#  'sahil_ku_11',
#  'shubham_verma_181',
#  '03arnav9',
#  'sancchhita',
#  '_adi_tea_yeah_',
#  'soumya_05mohanty',
#  'prachipratikhya_27',
#  'shadezahrai',
#  'queen_priti_1_2_',
#  'readchoi',
#  '_anshuman_p_',
#  'atty.subhrajyoti',
#  'simonsinek',
#  'askvinh',
#  'pratyush_kumar_sahu23',
#  'me_luciess',
#  'swasteek._7',
#  'mona____lisha_____',
#  'sgt.sameer123',
#  'singh.aryan.45',
#  'ankittmohantty',
#  '__santosh_dalei___2005',
#  'hansita_samantray',
#  'i_amdkd',
#  'dasoham_',
#  'musictravellove',
#  'neel__1201',
#  'star_lord.ashu',
#  '_praptii.14',
#  '_.kiransai._',
#  'abhijeettt.w_',
#  '_.kulcha._20',
#  'shreshtha_pattnaik',
#  'anindita7943',
#  'dinesh25214',
#  'jazz_scotch_',
#  'rutuparna_mishra19',
#  'simplifyinterviews',
#  'll_sahani_babu_ll',
#  'sajjaad.khader',
# ...

# %%
gadar=[]
for i in followings:
  if i not in followers:
    gadar.append(i)
gadar
# Out:
# ['side_end_developer__',
#  'hiten.codes',
#  'sheenamgautam',
#  'fecpodcast',
#  'zorothewiz',
#  'shadezahrai',
#  'readchoi',
#  'simonsinek',
#  'askvinh',
#  'singh.aryan.45',
#  'dasoham_',
#  'musictravellove',
#  'simplifyinterviews',
#  'sajjaad.khader',
#  'technical_sapien',
#  'arshgoyalyt',
#  'prasoonpratham',
#  'overpowered.ai',
#  'ezsnippet',
#  'spc_iitmbs',
#  'switch.sitbbsr',
#  'silicontech_bbs',
#  'sanidhya.ai',
#  'jerryjhlee',
#  'paradox_iitmadras',
#  'shwetaarora.in',
#  'natgeo',
#  'iitmadras_bs',
#  'discovery',
#  'cnn']
